# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelleitedasilva/projetoFinalBCC/blob/main/C%C3%B3pia_de_Finan%C3%A7as_Corporativas_BCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **UFABC - UNIVERSIDADE FEDERAL DO ABC**

# %% [markdown]
# ### *HISTÓRICO DE AÇÕES CORPORATIVAS*

# %% [markdown]
# > Emanuel Victor da Rocha Ângelo
# >
# > Rafael Leite da Silva

# %% [markdown]
# **Sumário:**
#
#
# *   1. Ação
# *   2. Valor de uma ação
# *   3. YFinance
# *   Item da lista

# %%
# !pip install yfinance
# !pip install get-all-tickers

# %%
from pandas.core.api import notnull
import yfinance as yf
import pandas_datareader.data as web
import pandas as pd


print("Digite a sigla da empresa na bolsa de valores para saber a sua evolução: ")
name_company = input("Sigla:")


ticker = yf.Ticker(name_company)
aapl_df = ticker.actions


aapl_df.plot(title=f"5 Years {ticker.info['shortName']}")
# Out:
# Digite a sigla da empresa na bolsa de valores para saber a sua evolução:
# Sigla:pbr

# %%
aapl_3mo = ticker.history(period="3mo")
aapl_3mo['Close'].plot(title=f"Three Months {ticker.info['shortName']}")
